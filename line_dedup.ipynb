# %%
from utils import *

# %%
data = load_jsonl('./2024_000.jsonl')
# Out:
# 79778it [00:02, 39149.27it/s]

# %%
import kss

# %%
from transformers import AutoTokenizer

# %%
model_path = '/home/work/user/ocw/sft/0711_mcore_10-7b_no_gqa_sft_600_fp32'

# %%
tokenizer = AutoTokenizer.from_pretrained(model_path, trust_remote_code=True)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
from tqdm import tqdm

# %%
 (user/ocw/plm/10.7b_no_gqa_240615_add_data_hf_27.5k_fp32/modeling_midm.pydd

# %%
sentences = []
for i in tqdm(data):
    sentences.extend(kss.split_sentences(i['text']))
# Out:
# 100% 79778/79778 [00:13<00:00, 5717.89it/s]

# %%
from collections import Counter

# %%
tmp = Counter(sentences).most_common()

# %%
tmp_upper_6 = [i for i in tmp if i[1]>=6]

# %%
len(tmp_upper_6)
# Out:
# 695

# %%
len(sentences)
# Out:
# 1506020

# %%
for i in tmp_upper_6:
    print(i)
# Out:
# ('감사합니다.', 961)
# ('안녕하세요', 502)
# ('안녕하세요.', 340)
# ('나.', 256)
# ('감사합니다', 255)
# ('다.', 214)
# ('이 기사가 유용하다고 생각되면 다른 사람들과 공유하십시오.', 199)
# ('매우 감사합니다.', 199)
# ('안녕하세요,', 129)
# ('감사합니다!', 110)
# ('안녕하세요!', 102)
# ('»', 94)
# ('좋아요', 94)
# ('여러분의 지식으로 알차게 문서를 완성해 갑시다.', 91)
# ('추천합니다.', 91)
# ('기프트조아에서 상담 받아보세요.', 69)
# ('아니요.', 68)
# ('조여주는 힘 찾아봤죠.', 68)
# ('마.', 67)
# ('그렇습니다.', 66)
# ('안녕하세요?', 60)
# ('인생에서 도움이 될 값진 경험 많이 하고 오시길 바랍니다.', 59)
# ('언제나 화이팅 하시고 어려운 일이 있으시면 언제든 연락 주세요. ^^', 59)
# ('한다.', 58)
# ('네요.', 57)
# ('더 알고싶으시면 본문을 클릭해주세요.', 56)
# ('궁금한 사항은 본문을 참고하시기 바랍니다.', 53)
# ('궁금한 내용은 본문을 참고하시기 바랍니다.', 53)
# (':)', 52)
# ('아.', 52)
# ('감사합니다^^', 52)
# ('그렇다.', 52)
# ('추천해 드릴까요?', 51)
# ('바람빠지는 소리 났죠.', 50)
# ('아닙니다.', 48)
# ('아!', 45)
# ('그라나도 에스파다 GM팀 입니다.', 45)
# ('질에서 바람소리 나더라구요.', 44)
# ('아..', 44)
# ('이것은 질문 이지요', 44)
# ('입니다.', 43)
# ('마사지를 잘해요', 43)
# ('요실금 치료 방법 알아봤어요.', 42)
# ('안녕하세요~', 41)
# ('리한입니다.', 41)
# ('아...', 40)
# ('더블 클릭하여 편집하세요.', 40)
# ...
