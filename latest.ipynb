# %%
from tqdm import tqdm
import multiprocessing
import json
import os
import copy
import datatrove
from utils import *
import argparse
from datatrove.pipeline.filters import (
    C4QualityFilter,
    FineWebQualityFilter,
    GopherQualityFilter,
    GopherRepetitionFilter,
    LanguageFilter,
    URLFilter,
)
from datatrove.data import Document
from typing import List
import time

# %%
def get_args():
    # parser
    parser = argparse.ArgumentParser()
    parser.add_argument('--output_dir', type=str, help = 'output 위치',default='/home/work/user/ocw/kt_output/heuristic_filtering/2021-04/test')
    parser.add_argument('--input_dir', type=str, help = 'output 위치',default='/home/work/user/wjpark/midm_pack/data/2021-04/remove_duplicate')
    parser.add_argument('--filter_name', type=str, help = 'output 위치',default='url')
    args,_  = parser.parse_known_args()
    return args

def apply_filter(filter_for_fineweb, dataset:List[datatrove.data.Document], filter_name):
    after = []
    filtered = []
    for i in tqdm(dataset,desc=filter_name):
        if filter_for_fineweb.filter(i)==True:
            after.append(i)
        else:
            filtered.append(i)
    print(f'size of dataset before {filter_name} filtering - {len(dataset)}')
    print(f'size of dataset after {filter_name} filtering - {len(after)}')
    return after, filtered

def map_filter(in_path, out_path):
    name = (os.path.split(in_path[0])[1]).split('jsonl')[0]
    output_path = os.path.split(out_path)[0]
    # read
    dataset = load_jsonl(in_path)
    dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
    # url
    url_filter=URLFilter()
    dataset_url, filtered = apply_filter(url_filter, dataset, 'url')
    # save
    filtered = [i.metadata for i in filtered]
    save_jsonl(os.path.join(output_path, 'url/removed'), filtered, name)
    
    gopher_repetition_filter = GopherRepetitionFilter(language='ko')
    dataset_gopher_repetition, filtered = apply_filter(gopher_repetition_filter, dataset_url, 'gopher_rep')
    # save
    filtered = [i.metadata for i in filtered]
    save_jsonl(os.path.join(output_path, 'url/gopher_rep'), filtered, name)
    
    gopher_quality_filter = GopherQualityFilter(min_stop_words=None,language='ko')
    dataset_gopher_quality, filtered = apply_filter(gopher_quality_filter, dataset_gopher_repetition, 'gopher_quality')
    # save
    filtered = [i.metadata for i in filtered]
    save_jsonl(os.path.join(output_path, 'url/gopher_quality'), filtered, name)
    
    c4_filter = C4QualityFilter(filter_no_terminal_punct=False,language='ko')
    dataset_c4, filtered = apply_filter(c4_filter, dataset_gopher_quality, 'c4')
    # save
    filtered = [i.metadata for i in filtered]
    save_jsonl(os.path.join(output_path, 'url/c4'), filtered, name)
    
    # output
    output = [i.metadata for i in c4_filter]
    save_jsonl(output_path, output, name)

if __name__=='__main__':
    args = get_args()
    path = args.input_dir
    output_dir = args.output_dir
    filter_name = args.filter_name
    data_list = [i for i in os.listdir(path) if i.endswith('part')]
    cpu_count = os.cpu_count()
    os.makedirs(output_dir, exist_ok=True)
    for filter_name in ['url','gopher_rep','gopher_quality','c4']:
        os.makedirs(os.path.join(output_dir,f'{filter_name}/removed'), exist_ok=True)

# %%
now = time.time()
pool = multiprocessing.Pool(processes=cpu_count)

for i in tqdm(range(0,len(data_list),cpu_count)):
    in_paths = [os.path.join(path, j) for j in data_list[i:i+cpu_count]]
    out_paths = [os.path.join(output_dir, os.path.splitext(j)[0]) for j in data_list[i:i+cpu_count]]
    inputs = [(a,b) for a,b in zip(in_paths, out_paths)]
    pool.starmap(map_filter, inputs)#['p1','p2','p3','p4'])
print(time.time()-now)
pool.close()
pool.join()
# Out:
# url: 100% 1968/1968 [00:02<00:00, 730.06it/s]
# size of dataset before filtering - 1968
# size of dataset after filtering - 1960
# url: 100% 1993/1993 [00:02<00:00, 740.81it/s]
# size of dataset before filtering - 1993
# size of dataset after filtering - 1990
# url: 100% 1844/1844 [00:02<00:00, 687.97it/s]
# size of dataset before filtering - 1844
# size of dataset after filtering - 1840
# 100% 3/3 [00:00<00:00, 12697.19it/s]
# 100% 8/8 [00:00<00:00, 10578.32it/s]t/s]
# 100% 4/4 [00:00<00:00, 12000.87it/s]t/s]
#   0% 0/2 [00:15<?, ?it/s][00:12<01:55, 15.20it/s]]Process ForkPoolWorker-32:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-64:
# Traceback (most recent call last):
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-62:
# Traceback (most recent call last):
# Process ForkPoolWorker-53:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-41:
# Traceback (most recent call last):
# Process ForkPoolWorker-61:
# Traceback (most recent call last):
# Process ForkPoolWorker-47:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-33:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-17:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Process ForkPoolWorker-14:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-35:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# gopher_rep:   5% 97/1960 [00:12<03:35,  8.64it/s]  File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-18:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-26:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-12:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-24:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-48:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Process ForkPoolWorker-38:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-8:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#
#
# KeyboardInterrupt
#
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-54:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
# Traceback (most recent call last):
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
# Process ForkPoolWorker-13:
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Process ForkPoolWorker-6:
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "<string>", line 2, in __init__
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# url:   0% 0/96400 [00:00<?, ?it/s]  File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "<string>", line 2, in __init__
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 2, in __init__
#
#   File "<string>", line 5, in __init__
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# KeyboardInterrupt
# Process ForkPoolWorker-11:
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 5, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
#   File "<string>", line 5, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
# KeyboardInterrupt
#   File "<string>", line 5, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
#   File "<string>", line 2, in __init__
# Process ForkPoolWorker-27:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "<string>", line 2, in __init__
#   File "<string>", line 5, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_9822/2008641089.py", line 30, in map_filter
#     dataset_url, filtered = apply_filter(url_filter, dataset, 'url')
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-19:
#   File "/tmp/ipykernel_9822/2008641089.py", line 14, in apply_filter
#     if filter_for_fineweb.filter(i)==True:
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.10/site-packages/datatrove/pipeline/filters/url_filter.py", line 107, in filter
#     self.download_data()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/work/.local/lib/python3.10/site-packages/datatrove/pipeline/filters/url_filter.py", line 94, in download_data
#     self.block_listed_domains = get_list(
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/work/.local/lib/python3.10/site-packages/datatrove/pipeline/filters/url_filter.py", line 30, in get_list
#     return parse_list(f, do_normalize).union(extra)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/home/work/.local/lib/python3.10/site-packages/datatrove/pipeline/filters/url_filter.py", line 25, in parse_list
#     return {normalize(x) if do_normalize else x.strip() for x in line if x[0] != "#"}
#   File "/home/work/.local/lib/python3.10/site-packages/datatrove/pipeline/filters/url_filter.py", line 25, in <setcomp>
#     return {normalize(x) if do_normalize else x.strip() for x in line if x[0] != "#"}
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-7:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
# Process ForkPoolWorker-34:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-5:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-58:
# Traceback (most recent call last):
# Process ForkPoolWorker-3:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "<string>", line 5, in __init__
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-23:
# Process ForkPoolWorker-15:
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# Process ForkPoolWorker-20:
# Traceback (most recent call last):
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
# Process ForkPoolWorker-60:
#   File "<string>", line 5, in __init__
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Process ForkPoolWorker-22:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
#   File "<string>", line 2, in __init__
# Process ForkPoolWorker-63:
# Process ForkPoolWorker-25:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-46:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Traceback (most recent call last):
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "<string>", line 2, in __init__
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
# Process ForkPoolWorker-21:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# gopher_rep:   5% 99/1960 [00:13<04:02,  7.67it/s]  File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
# gopher_rep:   5% 101/1960 [00:13<03:38,  8.51it/s]Process ForkPoolWorker-51:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 5, in __init__
# KeyboardInterrupt
# gopher_rep:   5% 107/1960 [00:13<02:52, 10.74it/s]Process ForkPoolWorker-52:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in map_filter
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "/tmp/ipykernel_9822/2008641089.py", line 27, in <listcomp>
#     dataset = [Document(text=i['text'], id=i['adlr_id'], metadata=i) for i in dataset]
#   File "<string>", line 2, in __init__
# KeyboardInterrupt
# gopher_rep:  16% 298/1840 [00:32<01:55, 13.33it/s]
